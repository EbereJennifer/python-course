# %%
# 3)
# Mit Python Arrays folgende Operationen definieren:
# Addition und Subtraktion zweier Vektoren, Skalarmultiplikation Zahl*Vektor.
# Falls nötig, Definitionen recherchieren.


import array

def subtract(v1, v2):
    v3 = scalar_multiply(-1, v2)
    v4 = add(v1, v3)
    return v4


def add(v1, v2):
    assert len(v1) == len(v2)
    zipped = zip(v1, v2)
    liste = [a+b for a, b in zipped]
    return array.array("i", liste)


def scalar_multiply(n, vector):
    return array.array("i", [n * a for a in vector])


arr1 = array.array("i", [3, 6, -2, 7, 13])
arr2 = array.array("i", [0, 2, 2, 11, 3])

add(arr1, arr2), add(arr1, arr1)

# %%
scalar_multiply(3, arr1)

# %%
subtract(arr1, arr2)

# %%
from array import array as erzeuge_vector
vector = erzeuge_vector("i", [2, -3, 5, 8, 1, 7, -5, 9, 1])
add(vector, vector)

# %%
scalar_multiply(7, vector)

# %%
# Ü: Neue Operation implementieren: Skalarprodukt zwischen zwei Vectoren
import array
def skalarprodukt(v1, v2):
    assert len(v1) == v2
    zipped = zip(v1, v2)

    product = [skalarprodukt(v1, v2) for v1, v2 in zipped]
    return array.array("i", product)

v1 = [2, 5, 6, 8, 9]
v2 = [5, 2, 4, 1, 3]

skalarprodukt(v1, v2)

# %%
# correction from Anton

def skalarprodukt(v1, v2):
    return[paar for paar in zip(v1, v2)]

vector, arr1, skalarprodukt(vector, arr1)
# Out:
# (array('i', [2, -3, 5, 8, 1, 7, -5, 9, 1]),
#  array('i', [3, 6, -2, 7, 13]),
#  [(2, 3), (-3, 6), (5, -2), (8, 7), (1, 13)])

# %%
# correction from Anton

def skalarprodukt(v1, v2):

    return sum([a * b for a, b in zip(v1, v2)])

skalarprodukt(vector, arr1)
# Out:
# 47

# %%
def skalarprodukt(v1, v2):
    """
    Berechnet das Skalarprodukt zweier gleichlanger Vektoren.

    Parameter:
    v1: Erster Vektor
    v2: Zweiter Vektor

    Raises:
        ValveError, falls Parameter unterschiedlich lang
    """
    if len(v1) != len(v2):
        raise ValueError("Länge der Vektoren muss gleich sein")
    return sum([a * b for a, b in zip(v1, v2)])


skalarprodukt(arr2, arr1)
# Out:
# 124
