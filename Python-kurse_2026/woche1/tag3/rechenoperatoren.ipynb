# %%
# in diese zelle kann python code geschrieben werden
s = "Hallo, Welt"
print(s)
#shift+Enter
# Out:
# Hallo, Welt

# %%
import builtins

float = builtins.float

# %%
#output ohne print möglich: werte der letzen Zeile werden ausgegeben
#False
"Sonne", 3 + 7, 3.2345, True

# %%
print("Python")
print("Java")
"Kotlin"

# %%
# / Exakte Division (Ergebnis als kommazahl)
# // int Division, Ergebnis also ganze Zahl
# ** Potenzoperation (exponential) "2 hoch 3"
# % Modulo operation gives the remainder instead,  after a division is carried out
5 / 3, 5 // 3, 2 ** 3, 10 % 3

# %%
#logische Operatoren: and, or, not
True and False, True or False, not True, True or True

# %%
#Predefined functions: print, help, input, type
n = input("enter a number: ")
print(n)

# %%
b1 = True
b2 = False
# Ü: mit and, or, not ein exklusives Oder definieren: Genau eines ist wahr
#Use “and,” “or,” and “not” to define an exclusive OR: Exactly one of them is true
(b1 and not b2) or (b2 and not b1)
b1 != b2  #umgleich

# %%
False < True, True < False, "see" < "Tee"

# %%
30 >= 33 >= 25, 30 >= 33

# %%
#vordefinierte Funktionen: print, help, input, type
n = input("Geben Sie eine Zahl ein: ")
print(n)

# %%
#vordefinierte Funktionen: print, help, input, type
string = input("Geben Sie eine Zahl ein: ")
n = int(string)
type(string), string, type(n), n

# %%
decimal_value = float(input("Geben Sie eine float: "))

type(decimal_value), decimal_value
# Out:
# (float, 5.0)

# %%
zahl_als_string = input("Eingebe Zahl")
zahl = int(zahl_als_string)
# fallunterscheidung, if-statement
if zahl > 0:
    print("Dar war eine positive Zahl.")
elif zahl == 0:
    print("Das war eine Null.")
else:
    print("Das war eine negative Zahl.")

# %%
#empty values prints false
bool("")  # False
bool("Hi")  # True
bool([])  # False
bool([1, 2])  # True
bool(0)  #False
#bool(none)   NameError: name 'none' is not defined

# %%
print("*" * 10)
# Out:
# **********
