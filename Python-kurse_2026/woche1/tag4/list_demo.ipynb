# %%
# Liste kann mehrere Elemente enthalten

namen = ["Meier", "Güler", "Kim"]
namen
# Out:
# ['Meier', 'Güler', 'Kim']

# %%
import random #Durch den Import stehen alle Funktionen aus random bereit und können hier verwendet werden.
              #Once imported, all functions from `random` are available and can be used here

element = random.choice(namen)
element
# Out:
# 'Kim'

# %%
for s in namen: #Für jedes Element s in der Liste namen
    print(s)
# Out:
# Meier
# Güler
# Kim

# %%
dir(56)

# %%
dir(random.random())

# %%
dir("blessed") #shows all the methods for strings
