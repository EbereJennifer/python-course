# %%
# Beginner Level

# 1. Write a program to generate a random number between 1 and 10.
import random
zufallzahlen = random.randint(1,10)
print(zufallzahlen)

# %%
#2. Use random.choice() to pick a random fruit from a list.
import random
fruits = ["apple", "banana", "cherry"]
random.choice(fruits)

# %%
# 3. Generate a random floating-point number between 0 and 1.
import random
random.random()

# %%
# 4. Write a program to simulate a coin toss (Heads or Tails).
import random

print(random.choice(["Heads", "Tails"]))

# %%
# 5. Generate a random number between 50 and 100.

import random
random.randint(50,100)

# %%
# Intermediate Level

# 6. Create a list of 5 random integers between 1 and 20.

import random
funf_zafallzahl = [random.randint(1,20) for _ in range(5)]
print(funf_zafallzahl)

# %%
# 7. Shuffle a list of numbers using random.shuffle().
import random
n = [3, 4, 7, 8, 19, 45]
random.shuffle(n)
print(n)

# %%
# 8. Write a program to simulate rolling a dice (1–6).

import random
print(random.randint(1, 6))
# Out:
# 5

# %%
# 9. Pick 3 random elements from a list without repetition using random.sample()

import random
n = [3, 4, 7, 8, 19, 45, 6, 9, 12, 14]
print(random.sample(n, 3))
import string
help(string.ascii_letters)
# Out:
# [45, 14, 6]
# No Python documentation found for 'abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ'.
# Use help() to get the interactive help utility.
# Use help(str) for help on the str class.

# %%
# 10.  Generate a random password using letters and numbers.

import random

import random
import string
chars = string.ascii_letters + string.digits
password = "".join(random.choice(chars) for i in range(8))
print(password)
# Out:
# N0jRxw43

# %%
# Generate a random OTP (6-digit code).
# Simulate 100 coin tosses and count how many times heads appears.
# Create a program that randomly assigns students into 3 groups.

# 11. Simulate a lottery system that picks 6 unique numbers from 1–49.

import random
print(random.sample(range(1, 50), 6))
# Out:
# [20, 6, 35, 32, 45, 32]

# %%
# Create a number guessing game where the computer picks a random number and the user guesses it.
import random
num = random.randint(1,100)
guess = int(input("Guess a number:"))
if guess == num:
    print("Correct")
else:
    print(f"Wrong: The correct number was {num}" )
# Out:
# Wrong: The correct number was 61
