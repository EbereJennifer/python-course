# %%
from pickletools import dis

dictionary = {
    "chair": "stuhl",
    "street":"straße",
    "town": "stadt"
}
print(dictionary)
for elem in dictionary:
    print(elem)
# Out:
# {'chair': 'stuhl', 'street': 'straße', 'town': 'stadt'}
# chair
# street
# town

# %%
if "town" in dictionary:
    print("town ist vorhanden")
# Out:
# town ist vorhanden

# %%
if "city" in dictionary:
    print("city ist vorhanden")
else:
    print("city ist nicht vorhanden")
# Out:
# city ist nicht vorhanden

# %%
"""
testet auf Mitgliedschaft, bei dict auf keys bezogen
auch bei set möglich und einigen anderen Typen möglich
"""
3 in{2, 3, 4}
# Out:
# True

# %%
"""
# # Update
auch bei set möglich und einigen anderen Typen möglich
"""

dictionary["chair"] = "stuhl"
dictionary["chair"]
# Out:
# 'stuhl'

# %%
# Neues Element
dictionary["red"] = "rot"
dictionary["red"]

# %%
new_items = {
    "blue": "blau",
    "black": "schwarz"
}
dictionary.update(new_items)
dictionary
# Out:
# {'chair': 'stuhl',
#  'street': 'straße',
#  'town': 'stadt',
#  'blue': 'blau',
#  'black': 'schwarz'}

# %%
#values: Alle Typen erlaubt
# keys: wie bei set, viele Typen nicht erlaubt
#forbidden = {[1,2,3]: "123}
allowed = {"123": [1,2,3]}

# %%
#Ü: Dictionary anlegen: keys sind Teiler der Zahl, values Ergebnis der Division
# bei 12: {2: 5, 3:4, 4:3, 6: 2}
n = 172436

result = {}
for i in range (2, n // 2 + 1):
    pass

# %%
n = 172438
result = {}

for i in range(2, n // 2 + 1):
    if n % i == 0:     # even number
        result[i] = n // i  # integer division
print(result)
# Out:
# {2: 86219, 7: 24634, 14: 12317, 109: 1582, 113: 1526, 218: 791, 226: 763, 763: 226, 791: 218, 1526: 113, 1582: 109, 12317: 14, 24634: 7, 86219: 2}

# %%
result.keys()
# Out:
# dict_keys([2, 7, 14, 109, 113, 218, 226, 763, 791, 1526, 1582, 12317, 24634, 86219])

# %%
result.values()
# Out:
# dict_values([86219, 24634, 12317, 1582, 1526, 791, 763, 226, 218, 113, 109, 14, 7, 2])

# %%
result.items()
# Out:
# dict_items([(2, 86219), (7, 24634), (14, 12317), (109, 1582), (113, 1526), (218, 791), (226, 763), (763, 226), (791, 218), (1526, 113), (1582, 109), (12317, 14), (24634, 7), (86219, 2)])

# %%
n = 12
result = {}

for i in range(2, n):  # start from 2 (exclude 1 if not needed)
    if n % i == 0:     # check if i is a divisor
        result[i] = n // i  # integer division

print(result)
