# %%
""""
Data” usually means information stored in files, for example:

.txt → text files
.csv → tables
.json → structured data

What is an “Ordner” (directory)?

An Ordner (folder/directory) is just a container for files.

Example structure:

project/
│
├── data/
│   └── names.txt
├── script.py
project → main folder
data → subfolder
names.txt → file
"""






import pathlib    # pathlib is a general module

# %%
pfad = pathlib.Path("tmp/meinedatei") # .Path checks if a file exists or if a file in a directory has been created. tmp means temporal file
pathlib.Path.exists(pfad)

# %%
# Kürzere Möglichkeit für import einzelner Elemente
from pathlib import Path
datei = Path("C:/", "Users", "golem", "meinedatei.txt")
Path.exists(datei)

# %%
# Kürzere Möglichkeit für import einzelner Elemente
from pathlib import Path
datei = Path("C:/", "Users", "golem", "meinedatei.txt")
datei.expanduser()

# %%
datei = Path("~", "Dokument").expanduser()#this sign is called Tilde. Str+Alt+, AltGr+it says where the home/user directory is # .expanduser() prints the path that is supplied
datei, Path.exists(datei)

# %%
datei1 = Path("meinedatei.txt")
datei2 = Path("C:/", "Users", "Administrator", "test.txt")

datei1.exists()

# %%
datei1 = Path("meinedatei.txt")
datei2 = Path("C:/", "Users", "Administrator", "test.txt")

datei1.exists(), datei1.is_file(), datei1.is_dir(), datei1.name

# datei1.is_file()- Checks if it is a file (not a folder).
# datei1.is_dir()- Checks if it is a directory (folder).
# datei1.name- Gives just the file name, not the full path.

# %%
datei2.parts, datei2.stem  #stem gives only the name of the datei

# %%
datei2.parent

# %%
pfad = Path("daten.txt")
pfad.absolute()

# %%
pfad = Path("daten.txt")  #we created a new file in tag8 named daten.txt
pfad.absolute()
pfad.exists()

# %%
datei = open("daten.txt", mode="r")   #with (Strg+Leertaste), you can get path, daten.txt etc
inhalt = datei.read()
datei.close()

print(inhalt)

# %%
datei = open("einkaufsliste.txtx", mode="w") # Bei Bedarf überschreiben
datei.write("Brot, Zucker, Mehl")
datei.close()

# %%
path = Path("einkaufsListe.txt")
path.absolute()

# %%
datei = open("einkaufsListe.txt", mode="a")  #anhängen
datei.write("\nSalz, Pfeffer")
datei.close()

# %%
datei = open("einkaufsListe.txt", mode="a")
datei.write("\nknoblauch")
datei.close()

# %%
try:
    datei = open("falsch.txt", mode="r")
except FileNotFoundError:
    datei = open("Datei wurde nicht gefunden")
print("dahinter")

# %%
Datei = open("name_und_nummern.txt", "r")
zeile1 = datei.readline()
zeile2 = datei.readline()
datei.close()
zeile1, zeile2

# %%
Datei = open("name_und_nummern.txt", "r")
alle_zeilen = datei.readlines()
datei.close()
type(alle_zeilen), alle_zeilen
