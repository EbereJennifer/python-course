# %% [markdown]
# #### Umgebungsvariable
# - Können in zwei Stufen eingerichtet werden: Für aktuellen benutzer im Betriebssystem, oder systemweit (dazu admin nötig)
# - Suchen nach Umgebungsvariablen in den Systemeinstellungen (Windowstaste, drittes Symbol von unten Drehrad "Einstellungen")
# - Ü: Umgebungsvariable finden und Beispiele nennen
# - Ü: Neue Umgebungsvariable FAVORITE_LANGUAGE mit Wert Python
# - Umgebungsvariable PATH ist schon vordefiniert.
# - Darin: Mehrere Verzeichnisse, wo Windows nach Programmen sucht
# - Ü: Den Ordner, der das Pycharm-Projekt enthält, an PATH anfügen
# - Mann kann sich wert einer Umgebungsvariable in Terminal anzeigen lassen, in der Eingabeaufforderung (command prompt): echo %PATH%
# - Ü: Eingabeaufforderung starten, PATH anzeigen lassen (Windows-Taste + R, cmd)
#
# #### Environment Variables
# - Can be set up in two ways: for the current user in the operating system, or system-wide (requires admin privileges)
# - Search for environment variables in System Settings (Windows key, third icon from the bottom, “Settings” wheel)
# - Exercise: Find the environment variable and provide examples
# - Exercise: Create a new environment variable FAVORITE_LANGUAGE with the value Python
# - The PATH environment variable is already predefined.
# - Contents: Multiple directories where Windows searches for programs
#
# - Exercise: Add the folder containing the Pycharm project to PATH

# %% [markdown]
# - Software wird oft als Zip-Datei bereitgestellt (komprimierte Datei, enthält Orderstruktur)
# - Um mit der Software arbeiten zu können, muss dieser Prozess rückgängig gemacht werden: Entpacken, z.B Kontextmenu für Zip-Datei (7-zip, Hier entpacken o.ä.)
# - Beim Entpacken der Postgres Binaries entsteht ein Ordner pgsql.
# - Darin gibt es Unterordner bin.
# - Ü: bin an PATH anhängen.
# - Ü: checken
#
#
# - Software is often provided as a ZIP file (a compressed file that contains a folder structure)
# - To use the software, you must unzip it: For example, use the context menu for the ZIP file (7-Zip, “Extract Here,” etc.).
# - When you unzip the Postgres binaries, a folder named `pgsql` is created.
# - Inside it, there is a subfolder named bin.
# - Add bin to the PATH.
